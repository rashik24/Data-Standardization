# %%
day_2 = {  'mwf': 'monday, wednesday, friday',
        'tth': 'tuesday, thursday',
        'mon-fri': 'monday, tuesday, wednesday, thursday, friday',
        'mon - fri':'monday, tuesday, wednesday, thursday, friday',
        'mon-sat': 'monday, tuesday, wednesday, thursday, friday, saturday',
        'm-f': 'monday, tuesday, wednesday, thursday, friday',
        'sat-sun': 'saturday, sunday',
        'tue-thu': 'tuesday, wednesday, thursday',
        'monday-friday':'monday, tuesday, wednesday, thursday, friday',
        'monday-thursday':'monday, tuesday, wednesday, thursday',
        'm-th' : 'monday, tuesday, wednesday, thursday'}
def generate_day_combinations():
    # Full day names and their abbreviations
    days = {
        'monday': ['mon', 'm'],
        'tuesday': ['tue', 'tu', 't'],
        'wednesday': ['wed', 'we', 'w'],
        'thursday': ['thu', 'th'],
        'friday': ['fri', 'fr', 'f'],
        'saturday': ['sat', 'sa', 's'],
        'sunday': ['sun', 'su']
    }

    # Function to get full day range
    def get_full_day_range(start_full, end_full):
        start_idx = list(days.keys()).index(start_full)
        end_idx = list(days.keys()).index(end_full)
        if start_idx == end_idx:
            return start_full
        return ', '.join(list(days.keys())[start_idx:end_idx + 1])

    # Create comprehensive mapping
    day_abbreviation_mapping = {}
    day_abbreviation_mapping.update(day_2)
    # Generate all possible day range combinations
    for start_full, start_abbrs in days.items():
        for end_full, end_abbrs in days.items():
            # Skip if start day comes after end day
            if list(days.keys()).index(start_full) > list(days.keys()).index(end_full):
                continue

            # Get the full day range
            full_day_range = get_full_day_range(start_full, end_full)

            # Add full day range
            day_abbreviation_mapping[f"{start_full}-{end_full}"] = full_day_range
            day_abbreviation_mapping[f"{start_full} - {end_full}"] = full_day_range
            day_abbreviation_mapping[f"{start_full} to {end_full}"] = full_day_range

            # Add combinations of abbreviations
            for start_abbr in start_abbrs:
                for end_abbr in end_abbrs:
                    combinations = [
                        f"{start_abbr}-{end_abbr}",
                        f"{start_abbr} - {end_abbr}",
                        f"{start_abbr} to {end_abbr}"
                    ]
                    for combo in combinations:
                        day_abbreviation_mapping[combo] = full_day_range

                    # Add combinations for mix of single and abbreviated names
                    if start_abbr != start_full:
                        day_abbreviation_mapping[f"{start_abbr}-{end_full}"] = full_day_range
                        day_abbreviation_mapping[f"{start_abbr} - {end_full}"] = full_day_range
                        day_abbreviation_mapping[f"{start_abbr} to {end_full}"] = full_day_range
                    if end_abbr != end_full:
                        day_abbreviation_mapping[f"{start_full}-{end_abbr}"] = full_day_range
                        day_abbreviation_mapping[f"{start_full} - {end_abbr}"] = full_day_range
                        day_abbreviation_mapping[f"{start_full} to {end_abbr}"] = full_day_range

    return day_abbreviation_mapping


# Generate the mapping
day_abbreviation_mapping = generate_day_combinations()

# Optional: Print or inspect the mapping
for key, value in day_abbreviation_mapping.items():
    print(f"{key}: {value}")
# Out:
# mwf: monday, wednesday, friday
# tth: tuesday, thursday
# mon-fri: monday, tuesday, wednesday, thursday, friday
# mon - fri: monday, tuesday, wednesday, thursday, friday
# mon-sat: monday, tuesday, wednesday, thursday, friday, saturday
# m-f: monday, tuesday, wednesday, thursday, friday
# sat-sun: saturday, sunday
# tue-thu: tuesday, wednesday, thursday
# monday-friday: monday, tuesday, wednesday, thursday, friday
# monday-thursday: monday, tuesday, wednesday, thursday
# m-th: monday, tuesday, wednesday, thursday
# monday-monday: monday
# monday - monday: monday
# monday to monday: monday
# mon-mon: monday
# mon - mon: monday
# mon to mon: monday
# mon-monday: monday
# mon - monday: monday
# mon to monday: monday
# monday-mon: monday
# monday - mon: monday
# monday to mon: monday
# mon-m: monday
# mon - m: monday
# mon to m: monday
# monday-m: monday
# monday - m: monday
# monday to m: monday
# m-mon: monday
# m - mon: monday
# m to mon: monday
# m-monday: monday
# m - monday: monday
# m to monday: monday
# m-m: monday
# m - m: monday
# m to m: monday
# monday-tuesday: monday, tuesday
# monday - tuesday: monday, tuesday
# monday to tuesday: monday, tuesday
# mon-tue: monday, tuesday
# mon - tue: monday, tuesday
# mon to tue: monday, tuesday
# mon-tuesday: monday, tuesday
# mon - tuesday: monday, tuesday
# mon to tuesday: monday, tuesday
# monday-tue: monday, tuesday
# monday - tue: monday, tuesday
# monday to tue: monday, tuesday
# mon-tu: monday, tuesday
# mon - tu: monday, tuesday
# mon to tu: monday, tuesday
# monday-tu: monday, tuesday
# monday - tu: monday, tuesday
# monday to tu: monday, tuesday
# mon-t: monday, tuesday
# mon - t: monday, tuesday
# mon to t: monday, tuesday
# monday-t: monday, tuesday
# monday - t: monday, tuesday
# monday to t: monday, tuesday
# m-tue: monday, tuesday
# m - tue: monday, tuesday
# m to tue: monday, tuesday
# m-tuesday: monday, tuesday
# m - tuesday: monday, tuesday
# m to tuesday: monday, tuesday
# m-tu: monday, tuesday
# m - tu: monday, tuesday
# m to tu: monday, tuesday
# m-t: monday, tuesday
# m - t: monday, tuesday
# m to t: monday, tuesday
# monday-wednesday: monday, tuesday, wednesday
# monday - wednesday: monday, tuesday, wednesday
# monday to wednesday: monday, tuesday, wednesday
# mon-wed: monday, tuesday, wednesday
# mon - wed: monday, tuesday, wednesday
# mon to wed: monday, tuesday, wednesday
# mon-wednesday: monday, tuesday, wednesday
# mon - wednesday: monday, tuesday, wednesday
# mon to wednesday: monday, tuesday, wednesday
# monday-wed: monday, tuesday, wednesday
# monday - wed: monday, tuesday, wednesday
# monday to wed: monday, tuesday, wednesday
# mon-we: monday, tuesday, wednesday
# mon - we: monday, tuesday, wednesday
# mon to we: monday, tuesday, wednesday
# monday-we: monday, tuesday, wednesday
# monday - we: monday, tuesday, wednesday
# monday to we: monday, tuesday, wednesday
# mon-w: monday, tuesday, wednesday
# mon - w: monday, tuesday, wednesday
# mon to w: monday, tuesday, wednesday
# monday-w: monday, tuesday, wednesday
# monday - w: monday, tuesday, wednesday
# monday to w: monday, tuesday, wednesday
# m-wed: monday, tuesday, wednesday
# m - wed: monday, tuesday, wednesday
# m to wed: monday, tuesday, wednesday
# m-wednesday: monday, tuesday, wednesday
# m - wednesday: monday, tuesday, wednesday
# m to wednesday: monday, tuesday, wednesday
# m-we: monday, tuesday, wednesday
# m - we: monday, tuesday, wednesday
# m to we: monday, tuesday, wednesday
# m-w: monday, tuesday, wednesday
# m - w: monday, tuesday, wednesday
# m to w: monday, tuesday, wednesday
# monday - thursday: monday, tuesday, wednesday, thursday
# monday to thursday: monday, tuesday, wednesday, thursday
# mon-thu: monday, tuesday, wednesday, thursday
# mon - thu: monday, tuesday, wednesday, thursday
# mon to thu: monday, tuesday, wednesday, thursday
# mon-thursday: monday, tuesday, wednesday, thursday
# mon - thursday: monday, tuesday, wednesday, thursday
# mon to thursday: monday, tuesday, wednesday, thursday
# monday-thu: monday, tuesday, wednesday, thursday
# monday - thu: monday, tuesday, wednesday, thursday
# monday to thu: monday, tuesday, wednesday, thursday
# mon-th: monday, tuesday, wednesday, thursday
# mon - th: monday, tuesday, wednesday, thursday
# mon to th: monday, tuesday, wednesday, thursday
# monday-th: monday, tuesday, wednesday, thursday
# monday - th: monday, tuesday, wednesday, thursday
# monday to th: monday, tuesday, wednesday, thursday
# m-thu: monday, tuesday, wednesday, thursday
# m - thu: monday, tuesday, wednesday, thursday
# m to thu: monday, tuesday, wednesday, thursday
# m-thursday: monday, tuesday, wednesday, thursday
# m - thursday: monday, tuesday, wednesday, thursday
# m to thursday: monday, tuesday, wednesday, thursday
# m - th: monday, tuesday, wednesday, thursday
# m to th: monday, tuesday, wednesday, thursday
# monday - friday: monday, tuesday, wednesday, thursday, friday
# monday to friday: monday, tuesday, wednesday, thursday, friday
# mon to fri: monday, tuesday, wednesday, thursday, friday
# mon-friday: monday, tuesday, wednesday, thursday, friday
# mon - friday: monday, tuesday, wednesday, thursday, friday
# mon to friday: monday, tuesday, wednesday, thursday, friday
# monday-fri: monday, tuesday, wednesday, thursday, friday
# monday - fri: monday, tuesday, wednesday, thursday, friday
# monday to fri: monday, tuesday, wednesday, thursday, friday
# mon-fr: monday, tuesday, wednesday, thursday, friday
# mon - fr: monday, tuesday, wednesday, thursday, friday
# mon to fr: monday, tuesday, wednesday, thursday, friday
# monday-fr: monday, tuesday, wednesday, thursday, friday
# monday - fr: monday, tuesday, wednesday, thursday, friday
# monday to fr: monday, tuesday, wednesday, thursday, friday
# mon-f: monday, tuesday, wednesday, thursday, friday
# mon - f: monday, tuesday, wednesday, thursday, friday
# mon to f: monday, tuesday, wednesday, thursday, friday
# monday-f: monday, tuesday, wednesday, thursday, friday
# monday - f: monday, tuesday, wednesday, thursday, friday
# monday to f: monday, tuesday, wednesday, thursday, friday
# m-fri: monday, tuesday, wednesday, thursday, friday
# m - fri: monday, tuesday, wednesday, thursday, friday
# m to fri: monday, tuesday, wednesday, thursday, friday
# m-friday: monday, tuesday, wednesday, thursday, friday
# m - friday: monday, tuesday, wednesday, thursday, friday
# m to friday: monday, tuesday, wednesday, thursday, friday
# m-fr: monday, tuesday, wednesday, thursday, friday
# m - fr: monday, tuesday, wednesday, thursday, friday
# m to fr: monday, tuesday, wednesday, thursday, friday
# m - f: monday, tuesday, wednesday, thursday, friday
# m to f: monday, tuesday, wednesday, thursday, friday
# monday-saturday: monday, tuesday, wednesday, thursday, friday, saturday
# monday - saturday: monday, tuesday, wednesday, thursday, friday, saturday
# monday to saturday: monday, tuesday, wednesday, thursday, friday, saturday
# mon - sat: monday, tuesday, wednesday, thursday, friday, saturday
# mon to sat: monday, tuesday, wednesday, thursday, friday, saturday
# mon-saturday: monday, tuesday, wednesday, thursday, friday, saturday
# mon - saturday: monday, tuesday, wednesday, thursday, friday, saturday
# mon to saturday: monday, tuesday, wednesday, thursday, friday, saturday
# monday-sat: monday, tuesday, wednesday, thursday, friday, saturday
# monday - sat: monday, tuesday, wednesday, thursday, friday, saturday
# monday to sat: monday, tuesday, wednesday, thursday, friday, saturday
# mon-sa: monday, tuesday, wednesday, thursday, friday, saturday
# mon - sa: monday, tuesday, wednesday, thursday, friday, saturday
# mon to sa: monday, tuesday, wednesday, thursday, friday, saturday
# monday-sa: monday, tuesday, wednesday, thursday, friday, saturday
# monday - sa: monday, tuesday, wednesday, thursday, friday, saturday
# monday to sa: monday, tuesday, wednesday, thursday, friday, saturday
# mon-s: monday, tuesday, wednesday, thursday, friday, saturday
# mon - s: monday, tuesday, wednesday, thursday, friday, saturday
# mon to s: monday, tuesday, wednesday, thursday, friday, saturday
# monday-s: monday, tuesday, wednesday, thursday, friday, saturday
# monday - s: monday, tuesday, wednesday, thursday, friday, saturday
# monday to s: monday, tuesday, wednesday, thursday, friday, saturday
# m-sat: monday, tuesday, wednesday, thursday, friday, saturday
# m - sat: monday, tuesday, wednesday, thursday, friday, saturday
# m to sat: monday, tuesday, wednesday, thursday, friday, saturday
# m-saturday: monday, tuesday, wednesday, thursday, friday, saturday
# m - saturday: monday, tuesday, wednesday, thursday, friday, saturday
# m to saturday: monday, tuesday, wednesday, thursday, friday, saturday
# m-sa: monday, tuesday, wednesday, thursday, friday, saturday
# m - sa: monday, tuesday, wednesday, thursday, friday, saturday
# m to sa: monday, tuesday, wednesday, thursday, friday, saturday
# m-s: monday, tuesday, wednesday, thursday, friday, saturday
# m - s: monday, tuesday, wednesday, thursday, friday, saturday
# m to s: monday, tuesday, wednesday, thursday, friday, saturday
# monday-sunday: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# monday - sunday: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# monday to sunday: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# mon-sun: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# mon - sun: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# mon to sun: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# mon-sunday: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# mon - sunday: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# mon to sunday: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# monday-sun: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# monday - sun: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# monday to sun: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# mon-su: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# mon - su: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# mon to su: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# monday-su: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# monday - su: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# monday to su: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# m-sun: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# m - sun: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# m to sun: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# m-sunday: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# m - sunday: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# m to sunday: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# m-su: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# m - su: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# m to su: monday, tuesday, wednesday, thursday, friday, saturday, sunday
# tuesday-tuesday: tuesday
# tuesday - tuesday: tuesday
# tuesday to tuesday: tuesday
# tue-tue: tuesday
# tue - tue: tuesday
# tue to tue: tuesday
# tue-tuesday: tuesday
# tue - tuesday: tuesday
# tue to tuesday: tuesday
# tuesday-tue: tuesday
# tuesday - tue: tuesday
# tuesday to tue: tuesday
# tue-tu: tuesday
# tue - tu: tuesday
# tue to tu: tuesday
# tuesday-tu: tuesday
# tuesday - tu: tuesday
# tuesday to tu: tuesday
# tue-t: tuesday
# tue - t: tuesday
# tue to t: tuesday
# tuesday-t: tuesday
# tuesday - t: tuesday
# tuesday to t: tuesday
# tu-tue: tuesday
# tu - tue: tuesday
# tu to tue: tuesday
# tu-tuesday: tuesday
# tu - tuesday: tuesday
# tu to tuesday: tuesday
# tu-tu: tuesday
# tu - tu: tuesday
# tu to tu: tuesday
# tu-t: tuesday
# tu - t: tuesday
# tu to t: tuesday
# t-tue: tuesday
# t - tue: tuesday
# t to tue: tuesday
# t-tuesday: tuesday
# t - tuesday: tuesday
# t to tuesday: tuesday
# t-tu: tuesday
# t - tu: tuesday
# t to tu: tuesday
# t-t: tuesday
# t - t: tuesday
# t to t: tuesday
# tuesday-wednesday: tuesday, wednesday
# tuesday - wednesday: tuesday, wednesday
# tuesday to wednesday: tuesday, wednesday
# tue-wed: tuesday, wednesday
# tue - wed: tuesday, wednesday
# tue to wed: tuesday, wednesday
# tue-wednesday: tuesday, wednesday
# tue - wednesday: tuesday, wednesday
# tue to wednesday: tuesday, wednesday
# tuesday-wed: tuesday, wednesday
# tuesday - wed: tuesday, wednesday
# tuesday to wed: tuesday, wednesday
# tue-we: tuesday, wednesday
# tue - we: tuesday, wednesday
# tue to we: tuesday, wednesday
# tuesday-we: tuesday, wednesday
# tuesday - we: tuesday, wednesday
# tuesday to we: tuesday, wednesday
# tue-w: tuesday, wednesday
# tue - w: tuesday, wednesday
# tue to w: tuesday, wednesday
# tuesday-w: tuesday, wednesday
# tuesday - w: tuesday, wednesday
# tuesday to w: tuesday, wednesday
# tu-wed: tuesday, wednesday
# tu - wed: tuesday, wednesday
# tu to wed: tuesday, wednesday
# tu-wednesday: tuesday, wednesday
# tu - wednesday: tuesday, wednesday
# tu to wednesday: tuesday, wednesday
# tu-we: tuesday, wednesday
# tu - we: tuesday, wednesday
# tu to we: tuesday, wednesday
# tu-w: tuesday, wednesday
# tu - w: tuesday, wednesday
# tu to w: tuesday, wednesday
# t-wed: tuesday, wednesday
# t - wed: tuesday, wednesday
# t to wed: tuesday, wednesday
# t-wednesday: tuesday, wednesday
# t - wednesday: tuesday, wednesday
# t to wednesday: tuesday, wednesday
# t-we: tuesday, wednesday
# t - we: tuesday, wednesday
# t to we: tuesday, wednesday
# t-w: tuesday, wednesday
# t - w: tuesday, wednesday
# t to w: tuesday, wednesday
# tuesday-thursday: tuesday, wednesday, thursday
# tuesday - thursday: tuesday, wednesday, thursday
# tuesday to thursday: tuesday, wednesday, thursday
# tue - thu: tuesday, wednesday, thursday
# tue to thu: tuesday, wednesday, thursday
# tue-thursday: tuesday, wednesday, thursday
# tue - thursday: tuesday, wednesday, thursday
# tue to thursday: tuesday, wednesday, thursday
# tuesday-thu: tuesday, wednesday, thursday
# tuesday - thu: tuesday, wednesday, thursday
# tuesday to thu: tuesday, wednesday, thursday
# tue-th: tuesday, wednesday, thursday
# tue - th: tuesday, wednesday, thursday
# tue to th: tuesday, wednesday, thursday
# tuesday-th: tuesday, wednesday, thursday
# tuesday - th: tuesday, wednesday, thursday
# tuesday to th: tuesday, wednesday, thursday
# tu-thu: tuesday, wednesday, thursday
# tu - thu: tuesday, wednesday, thursday
# tu to thu: tuesday, wednesday, thursday
# tu-thursday: tuesday, wednesday, thursday
# tu - thursday: tuesday, wednesday, thursday
# tu to thursday: tuesday, wednesday, thursday
# tu-th: tuesday, wednesday, thursday
# tu - th: tuesday, wednesday, thursday
# tu to th: tuesday, wednesday, thursday
# t-thu: tuesday, wednesday, thursday
# t - thu: tuesday, wednesday, thursday
# t to thu: tuesday, wednesday, thursday
# t-thursday: tuesday, wednesday, thursday
# t - thursday: tuesday, wednesday, thursday
# t to thursday: tuesday, wednesday, thursday
# t-th: tuesday, wednesday, thursday
# t - th: tuesday, wednesday, thursday
# t to th: tuesday, wednesday, thursday
# tuesday-friday: tuesday, wednesday, thursday, friday
# tuesday - friday: tuesday, wednesday, thursday, friday
# tuesday to friday: tuesday, wednesday, thursday, friday
# tue-fri: tuesday, wednesday, thursday, friday
# tue - fri: tuesday, wednesday, thursday, friday
# tue to fri: tuesday, wednesday, thursday, friday
# tue-friday: tuesday, wednesday, thursday, friday
# tue - friday: tuesday, wednesday, thursday, friday
# tue to friday: tuesday, wednesday, thursday, friday
# tuesday-fri: tuesday, wednesday, thursday, friday
# tuesday - fri: tuesday, wednesday, thursday, friday
# tuesday to fri: tuesday, wednesday, thursday, friday
# tue-fr: tuesday, wednesday, thursday, friday
# tue - fr: tuesday, wednesday, thursday, friday
# tue to fr: tuesday, wednesday, thursday, friday
# tuesday-fr: tuesday, wednesday, thursday, friday
# tuesday - fr: tuesday, wednesday, thursday, friday
# tuesday to fr: tuesday, wednesday, thursday, friday
# tue-f: tuesday, wednesday, thursday, friday
# tue - f: tuesday, wednesday, thursday, friday
# tue to f: tuesday, wednesday, thursday, friday
# tuesday-f: tuesday, wednesday, thursday, friday
# tuesday - f: tuesday, wednesday, thursday, friday
# tuesday to f: tuesday, wednesday, thursday, friday
# tu-fri: tuesday, wednesday, thursday, friday
# tu - fri: tuesday, wednesday, thursday, friday
# tu to fri: tuesday, wednesday, thursday, friday
# tu-friday: tuesday, wednesday, thursday, friday
# tu - friday: tuesday, wednesday, thursday, friday
# tu to friday: tuesday, wednesday, thursday, friday
# tu-fr: tuesday, wednesday, thursday, friday
# tu - fr: tuesday, wednesday, thursday, friday
# tu to fr: tuesday, wednesday, thursday, friday
# tu-f: tuesday, wednesday, thursday, friday
# tu - f: tuesday, wednesday, thursday, friday
# tu to f: tuesday, wednesday, thursday, friday
# t-fri: tuesday, wednesday, thursday, friday
# t - fri: tuesday, wednesday, thursday, friday
# t to fri: tuesday, wednesday, thursday, friday
# t-friday: tuesday, wednesday, thursday, friday
# t - friday: tuesday, wednesday, thursday, friday
# t to friday: tuesday, wednesday, thursday, friday
# t-fr: tuesday, wednesday, thursday, friday
# t - fr: tuesday, wednesday, thursday, friday
# t to fr: tuesday, wednesday, thursday, friday
# t-f: tuesday, wednesday, thursday, friday
# t - f: tuesday, wednesday, thursday, friday
# t to f: tuesday, wednesday, thursday, friday
# tuesday-saturday: tuesday, wednesday, thursday, friday, saturday
# tuesday - saturday: tuesday, wednesday, thursday, friday, saturday
# tuesday to saturday: tuesday, wednesday, thursday, friday, saturday
# tue-sat: tuesday, wednesday, thursday, friday, saturday
# tue - sat: tuesday, wednesday, thursday, friday, saturday
# tue to sat: tuesday, wednesday, thursday, friday, saturday
# tue-saturday: tuesday, wednesday, thursday, friday, saturday
# tue - saturday: tuesday, wednesday, thursday, friday, saturday
# tue to saturday: tuesday, wednesday, thursday, friday, saturday
# tuesday-sat: tuesday, wednesday, thursday, friday, saturday
# tuesday - sat: tuesday, wednesday, thursday, friday, saturday
# tuesday to sat: tuesday, wednesday, thursday, friday, saturday
# tue-sa: tuesday, wednesday, thursday, friday, saturday
# tue - sa: tuesday, wednesday, thursday, friday, saturday
# tue to sa: tuesday, wednesday, thursday, friday, saturday
# tuesday-sa: tuesday, wednesday, thursday, friday, saturday
# tuesday - sa: tuesday, wednesday, thursday, friday, saturday
# tuesday to sa: tuesday, wednesday, thursday, friday, saturday
# tue-s: tuesday, wednesday, thursday, friday, saturday
# tue - s: tuesday, wednesday, thursday, friday, saturday
# tue to s: tuesday, wednesday, thursday, friday, saturday
# tuesday-s: tuesday, wednesday, thursday, friday, saturday
# tuesday - s: tuesday, wednesday, thursday, friday, saturday
# tuesday to s: tuesday, wednesday, thursday, friday, saturday
# tu-sat: tuesday, wednesday, thursday, friday, saturday
# tu - sat: tuesday, wednesday, thursday, friday, saturday
# tu to sat: tuesday, wednesday, thursday, friday, saturday
# tu-saturday: tuesday, wednesday, thursday, friday, saturday
# tu - saturday: tuesday, wednesday, thursday, friday, saturday
# tu to saturday: tuesday, wednesday, thursday, friday, saturday
# tu-sa: tuesday, wednesday, thursday, friday, saturday
# tu - sa: tuesday, wednesday, thursday, friday, saturday
# tu to sa: tuesday, wednesday, thursday, friday, saturday
# tu-s: tuesday, wednesday, thursday, friday, saturday
# tu - s: tuesday, wednesday, thursday, friday, saturday
# tu to s: tuesday, wednesday, thursday, friday, saturday
# t-sat: tuesday, wednesday, thursday, friday, saturday
# t - sat: tuesday, wednesday, thursday, friday, saturday
# t to sat: tuesday, wednesday, thursday, friday, saturday
# t-saturday: tuesday, wednesday, thursday, friday, saturday
# t - saturday: tuesday, wednesday, thursday, friday, saturday
# t to saturday: tuesday, wednesday, thursday, friday, saturday
# t-sa: tuesday, wednesday, thursday, friday, saturday
# t - sa: tuesday, wednesday, thursday, friday, saturday
# t to sa: tuesday, wednesday, thursday, friday, saturday
# t-s: tuesday, wednesday, thursday, friday, saturday
# t - s: tuesday, wednesday, thursday, friday, saturday
# t to s: tuesday, wednesday, thursday, friday, saturday
# tuesday-sunday: tuesday, wednesday, thursday, friday, saturday, sunday
# tuesday - sunday: tuesday, wednesday, thursday, friday, saturday, sunday
# tuesday to sunday: tuesday, wednesday, thursday, friday, saturday, sunday
# tue-sun: tuesday, wednesday, thursday, friday, saturday, sunday
# tue - sun: tuesday, wednesday, thursday, friday, saturday, sunday
# tue to sun: tuesday, wednesday, thursday, friday, saturday, sunday
# tue-sunday: tuesday, wednesday, thursday, friday, saturday, sunday
# tue - sunday: tuesday, wednesday, thursday, friday, saturday, sunday
# tue to sunday: tuesday, wednesday, thursday, friday, saturday, sunday
# tuesday-sun: tuesday, wednesday, thursday, friday, saturday, sunday
# tuesday - sun: tuesday, wednesday, thursday, friday, saturday, sunday
# tuesday to sun: tuesday, wednesday, thursday, friday, saturday, sunday
# tue-su: tuesday, wednesday, thursday, friday, saturday, sunday
# tue - su: tuesday, wednesday, thursday, friday, saturday, sunday
# tue to su: tuesday, wednesday, thursday, friday, saturday, sunday
# tuesday-su: tuesday, wednesday, thursday, friday, saturday, sunday
# tuesday - su: tuesday, wednesday, thursday, friday, saturday, sunday
# tuesday to su: tuesday, wednesday, thursday, friday, saturday, sunday
# tu-sun: tuesday, wednesday, thursday, friday, saturday, sunday
# tu - sun: tuesday, wednesday, thursday, friday, saturday, sunday
# tu to sun: tuesday, wednesday, thursday, friday, saturday, sunday
# tu-sunday: tuesday, wednesday, thursday, friday, saturday, sunday
# tu - sunday: tuesday, wednesday, thursday, friday, saturday, sunday
# tu to sunday: tuesday, wednesday, thursday, friday, saturday, sunday
# tu-su: tuesday, wednesday, thursday, friday, saturday, sunday
# tu - su: tuesday, wednesday, thursday, friday, saturday, sunday
# tu to su: tuesday, wednesday, thursday, friday, saturday, sunday
# t-sun: tuesday, wednesday, thursday, friday, saturday, sunday
# t - sun: tuesday, wednesday, thursday, friday, saturday, sunday
# t to sun: tuesday, wednesday, thursday, friday, saturday, sunday
# t-sunday: tuesday, wednesday, thursday, friday, saturday, sunday
# t - sunday: tuesday, wednesday, thursday, friday, saturday, sunday
# t to sunday: tuesday, wednesday, thursday, friday, saturday, sunday
# t-su: tuesday, wednesday, thursday, friday, saturday, sunday
# t - su: tuesday, wednesday, thursday, friday, saturday, sunday
# t to su: tuesday, wednesday, thursday, friday, saturday, sunday
# wednesday-wednesday: wednesday
# wednesday - wednesday: wednesday
# wednesday to wednesday: wednesday
# wed-wed: wednesday
# wed - wed: wednesday
# wed to wed: wednesday
# wed-wednesday: wednesday
# wed - wednesday: wednesday
# wed to wednesday: wednesday
# wednesday-wed: wednesday
# wednesday - wed: wednesday
# wednesday to wed: wednesday
# wed-we: wednesday
# wed - we: wednesday
# wed to we: wednesday
# wednesday-we: wednesday
# wednesday - we: wednesday
# wednesday to we: wednesday
# wed-w: wednesday
# wed - w: wednesday
# wed to w: wednesday
# wednesday-w: wednesday
# wednesday - w: wednesday
# wednesday to w: wednesday
# we-wed: wednesday
# we - wed: wednesday
# we to wed: wednesday
# we-wednesday: wednesday
# we - wednesday: wednesday
# we to wednesday: wednesday
# we-we: wednesday
# we - we: wednesday
# we to we: wednesday
# we-w: wednesday
# we - w: wednesday
# we to w: wednesday
# w-wed: wednesday
# w - wed: wednesday
# w to wed: wednesday
# w-wednesday: wednesday
# w - wednesday: wednesday
# w to wednesday: wednesday
# w-we: wednesday
# w - we: wednesday
# w to we: wednesday
# w-w: wednesday
# w - w: wednesday
# w to w: wednesday
# wednesday-thursday: wednesday, thursday
# wednesday - thursday: wednesday, thursday
# wednesday to thursday: wednesday, thursday
# wed-thu: wednesday, thursday
# wed - thu: wednesday, thursday
# wed to thu: wednesday, thursday
# wed-thursday: wednesday, thursday
# wed - thursday: wednesday, thursday
# wed to thursday: wednesday, thursday
# wednesday-thu: wednesday, thursday
# wednesday - thu: wednesday, thursday
# wednesday to thu: wednesday, thursday
# wed-th: wednesday, thursday
# wed - th: wednesday, thursday
# wed to th: wednesday, thursday
# wednesday-th: wednesday, thursday
# wednesday - th: wednesday, thursday
# wednesday to th: wednesday, thursday
# we-thu: wednesday, thursday
# we - thu: wednesday, thursday
# we to thu: wednesday, thursday
# we-thursday: wednesday, thursday
# we - thursday: wednesday, thursday
# we to thursday: wednesday, thursday
# we-th: wednesday, thursday
# we - th: wednesday, thursday
# we to th: wednesday, thursday
# w-thu: wednesday, thursday
# w - thu: wednesday, thursday
# w to thu: wednesday, thursday
# w-thursday: wednesday, thursday
# w - thursday: wednesday, thursday
# w to thursday: wednesday, thursday
# w-th: wednesday, thursday
# w - th: wednesday, thursday
# w to th: wednesday, thursday
# wednesday-friday: wednesday, thursday, friday
# wednesday - friday: wednesday, thursday, friday
# wednesday to friday: wednesday, thursday, friday
# wed-fri: wednesday, thursday, friday
# wed - fri: wednesday, thursday, friday
# wed to fri: wednesday, thursday, friday
# wed-friday: wednesday, thursday, friday
# wed - friday: wednesday, thursday, friday
# wed to friday: wednesday, thursday, friday
# wednesday-fri: wednesday, thursday, friday
# wednesday - fri: wednesday, thursday, friday
# wednesday to fri: wednesday, thursday, friday
# wed-fr: wednesday, thursday, friday
# wed - fr: wednesday, thursday, friday
# wed to fr: wednesday, thursday, friday
# wednesday-fr: wednesday, thursday, friday
# wednesday - fr: wednesday, thursday, friday
# wednesday to fr: wednesday, thursday, friday
# wed-f: wednesday, thursday, friday
# wed - f: wednesday, thursday, friday
# wed to f: wednesday, thursday, friday
# wednesday-f: wednesday, thursday, friday
# wednesday - f: wednesday, thursday, friday
# wednesday to f: wednesday, thursday, friday
# we-fri: wednesday, thursday, friday
# we - fri: wednesday, thursday, friday
# we to fri: wednesday, thursday, friday
# we-friday: wednesday, thursday, friday
# we - friday: wednesday, thursday, friday
# we to friday: wednesday, thursday, friday
# we-fr: wednesday, thursday, friday
# we - fr: wednesday, thursday, friday
# we to fr: wednesday, thursday, friday
# we-f: wednesday, thursday, friday
# we - f: wednesday, thursday, friday
# we to f: wednesday, thursday, friday
# w-fri: wednesday, thursday, friday
# w - fri: wednesday, thursday, friday
# w to fri: wednesday, thursday, friday
# w-friday: wednesday, thursday, friday
# w - friday: wednesday, thursday, friday
# w to friday: wednesday, thursday, friday
# w-fr: wednesday, thursday, friday
# w - fr: wednesday, thursday, friday
# w to fr: wednesday, thursday, friday
# w-f: wednesday, thursday, friday
# w - f: wednesday, thursday, friday
# w to f: wednesday, thursday, friday
# wednesday-saturday: wednesday, thursday, friday, saturday
# wednesday - saturday: wednesday, thursday, friday, saturday
# wednesday to saturday: wednesday, thursday, friday, saturday
# wed-sat: wednesday, thursday, friday, saturday
# wed - sat: wednesday, thursday, friday, saturday
# wed to sat: wednesday, thursday, friday, saturday
# wed-saturday: wednesday, thursday, friday, saturday
# wed - saturday: wednesday, thursday, friday, saturday
# wed to saturday: wednesday, thursday, friday, saturday
# wednesday-sat: wednesday, thursday, friday, saturday
# wednesday - sat: wednesday, thursday, friday, saturday
# wednesday to sat: wednesday, thursday, friday, saturday
# wed-sa: wednesday, thursday, friday, saturday
# wed - sa: wednesday, thursday, friday, saturday
# wed to sa: wednesday, thursday, friday, saturday
# wednesday-sa: wednesday, thursday, friday, saturday
# wednesday - sa: wednesday, thursday, friday, saturday
# wednesday to sa: wednesday, thursday, friday, saturday
# wed-s: wednesday, thursday, friday, saturday
# wed - s: wednesday, thursday, friday, saturday
# wed to s: wednesday, thursday, friday, saturday
# wednesday-s: wednesday, thursday, friday, saturday
# wednesday - s: wednesday, thursday, friday, saturday
# wednesday to s: wednesday, thursday, friday, saturday
# we-sat: wednesday, thursday, friday, saturday
# we - sat: wednesday, thursday, friday, saturday
# we to sat: wednesday, thursday, friday, saturday
# we-saturday: wednesday, thursday, friday, saturday
# we - saturday: wednesday, thursday, friday, saturday
# we to saturday: wednesday, thursday, friday, saturday
# we-sa: wednesday, thursday, friday, saturday
# we - sa: wednesday, thursday, friday, saturday
# we to sa: wednesday, thursday, friday, saturday
# we-s: wednesday, thursday, friday, saturday
# we - s: wednesday, thursday, friday, saturday
# we to s: wednesday, thursday, friday, saturday
# w-sat: wednesday, thursday, friday, saturday
# w - sat: wednesday, thursday, friday, saturday
# w to sat: wednesday, thursday, friday, saturday
# w-saturday: wednesday, thursday, friday, saturday
# w - saturday: wednesday, thursday, friday, saturday
# w to saturday: wednesday, thursday, friday, saturday
# w-sa: wednesday, thursday, friday, saturday
# w - sa: wednesday, thursday, friday, saturday
# w to sa: wednesday, thursday, friday, saturday
# w-s: wednesday, thursday, friday, saturday
# w - s: wednesday, thursday, friday, saturday
# w to s: wednesday, thursday, friday, saturday
# wednesday-sunday: wednesday, thursday, friday, saturday, sunday
# wednesday - sunday: wednesday, thursday, friday, saturday, sunday
# wednesday to sunday: wednesday, thursday, friday, saturday, sunday
# wed-sun: wednesday, thursday, friday, saturday, sunday
# wed - sun: wednesday, thursday, friday, saturday, sunday
# wed to sun: wednesday, thursday, friday, saturday, sunday
# wed-sunday: wednesday, thursday, friday, saturday, sunday
# wed - sunday: wednesday, thursday, friday, saturday, sunday
# wed to sunday: wednesday, thursday, friday, saturday, sunday
# wednesday-sun: wednesday, thursday, friday, saturday, sunday
# wednesday - sun: wednesday, thursday, friday, saturday, sunday
# wednesday to sun: wednesday, thursday, friday, saturday, sunday
# wed-su: wednesday, thursday, friday, saturday, sunday
# wed - su: wednesday, thursday, friday, saturday, sunday
# wed to su: wednesday, thursday, friday, saturday, sunday
# wednesday-su: wednesday, thursday, friday, saturday, sunday
# wednesday - su: wednesday, thursday, friday, saturday, sunday
# wednesday to su: wednesday, thursday, friday, saturday, sunday
# we-sun: wednesday, thursday, friday, saturday, sunday
# we - sun: wednesday, thursday, friday, saturday, sunday
# we to sun: wednesday, thursday, friday, saturday, sunday
# we-sunday: wednesday, thursday, friday, saturday, sunday
# we - sunday: wednesday, thursday, friday, saturday, sunday
# we to sunday: wednesday, thursday, friday, saturday, sunday
# we-su: wednesday, thursday, friday, saturday, sunday
# we - su: wednesday, thursday, friday, saturday, sunday
# we to su: wednesday, thursday, friday, saturday, sunday
# w-sun: wednesday, thursday, friday, saturday, sunday
# w - sun: wednesday, thursday, friday, saturday, sunday
# w to sun: wednesday, thursday, friday, saturday, sunday
# w-sunday: wednesday, thursday, friday, saturday, sunday
# w - sunday: wednesday, thursday, friday, saturday, sunday
# w to sunday: wednesday, thursday, friday, saturday, sunday
# w-su: wednesday, thursday, friday, saturday, sunday
# w - su: wednesday, thursday, friday, saturday, sunday
# w to su: wednesday, thursday, friday, saturday, sunday
# thursday-thursday: thursday
# thursday - thursday: thursday
# thursday to thursday: thursday
# thu-thu: thursday
# thu - thu: thursday
# thu to thu: thursday
# thu-thursday: thursday
# thu - thursday: thursday
# thu to thursday: thursday
# thursday-thu: thursday
# thursday - thu: thursday
# thursday to thu: thursday
# thu-th: thursday
# thu - th: thursday
# thu to th: thursday
# thursday-th: thursday
# thursday - th: thursday
# thursday to th: thursday
# th-thu: thursday
# th - thu: thursday
# th to thu: thursday
# th-thursday: thursday
# th - thursday: thursday
# th to thursday: thursday
# th-th: thursday
# th - th: thursday
# th to th: thursday
# thursday-friday: thursday, friday
# thursday - friday: thursday, friday
# thursday to friday: thursday, friday
# thu-fri: thursday, friday
# thu - fri: thursday, friday
# thu to fri: thursday, friday
# thu-friday: thursday, friday
# thu - friday: thursday, friday
# thu to friday: thursday, friday
# thursday-fri: thursday, friday
# thursday - fri: thursday, friday
# thursday to fri: thursday, friday
# thu-fr: thursday, friday
# thu - fr: thursday, friday
# thu to fr: thursday, friday
# thursday-fr: thursday, friday
# thursday - fr: thursday, friday
# thursday to fr: thursday, friday
# thu-f: thursday, friday
# thu - f: thursday, friday
# thu to f: thursday, friday
# thursday-f: thursday, friday
# thursday - f: thursday, friday
# thursday to f: thursday, friday
# th-fri: thursday, friday
# th - fri: thursday, friday
# th to fri: thursday, friday
# th-friday: thursday, friday
# th - friday: thursday, friday
# th to friday: thursday, friday
# th-fr: thursday, friday
# th - fr: thursday, friday
# th to fr: thursday, friday
# th-f: thursday, friday
# th - f: thursday, friday
# th to f: thursday, friday
# thursday-saturday: thursday, friday, saturday
# thursday - saturday: thursday, friday, saturday
# thursday to saturday: thursday, friday, saturday
# thu-sat: thursday, friday, saturday
# thu - sat: thursday, friday, saturday
# thu to sat: thursday, friday, saturday
# thu-saturday: thursday, friday, saturday
# thu - saturday: thursday, friday, saturday
# thu to saturday: thursday, friday, saturday
# thursday-sat: thursday, friday, saturday
# thursday - sat: thursday, friday, saturday
# thursday to sat: thursday, friday, saturday
# thu-sa: thursday, friday, saturday
# thu - sa: thursday, friday, saturday
# thu to sa: thursday, friday, saturday
# thursday-sa: thursday, friday, saturday
# thursday - sa: thursday, friday, saturday
# thursday to sa: thursday, friday, saturday
# thu-s: thursday, friday, saturday
# thu - s: thursday, friday, saturday
# thu to s: thursday, friday, saturday
# thursday-s: thursday, friday, saturday
# thursday - s: thursday, friday, saturday
# thursday to s: thursday, friday, saturday
# th-sat: thursday, friday, saturday
# th - sat: thursday, friday, saturday
# th to sat: thursday, friday, saturday
# th-saturday: thursday, friday, saturday
# th - saturday: thursday, friday, saturday
# th to saturday: thursday, friday, saturday
# th-sa: thursday, friday, saturday
# th - sa: thursday, friday, saturday
# th to sa: thursday, friday, saturday
# th-s: thursday, friday, saturday
# th - s: thursday, friday, saturday
# th to s: thursday, friday, saturday
# thursday-sunday: thursday, friday, saturday, sunday
# thursday - sunday: thursday, friday, saturday, sunday
# thursday to sunday: thursday, friday, saturday, sunday
# thu-sun: thursday, friday, saturday, sunday
# thu - sun: thursday, friday, saturday, sunday
# thu to sun: thursday, friday, saturday, sunday
# thu-sunday: thursday, friday, saturday, sunday
# thu - sunday: thursday, friday, saturday, sunday
# thu to sunday: thursday, friday, saturday, sunday
# thursday-sun: thursday, friday, saturday, sunday
# thursday - sun: thursday, friday, saturday, sunday
# thursday to sun: thursday, friday, saturday, sunday
# thu-su: thursday, friday, saturday, sunday
# thu - su: thursday, friday, saturday, sunday
# thu to su: thursday, friday, saturday, sunday
# thursday-su: thursday, friday, saturday, sunday
# thursday - su: thursday, friday, saturday, sunday
# thursday to su: thursday, friday, saturday, sunday
# th-sun: thursday, friday, saturday, sunday
# th - sun: thursday, friday, saturday, sunday
# th to sun: thursday, friday, saturday, sunday
# th-sunday: thursday, friday, saturday, sunday
# th - sunday: thursday, friday, saturday, sunday
# th to sunday: thursday, friday, saturday, sunday
# th-su: thursday, friday, saturday, sunday
# th - su: thursday, friday, saturday, sunday
# th to su: thursday, friday, saturday, sunday
# friday-friday: friday
# friday - friday: friday
# friday to friday: friday
# fri-fri: friday
# fri - fri: friday
# fri to fri: friday
# fri-friday: friday
# fri - friday: friday
# fri to friday: friday
# friday-fri: friday
# friday - fri: friday
# friday to fri: friday
# fri-fr: friday
# fri - fr: friday
# fri to fr: friday
# friday-fr: friday
# friday - fr: friday
# friday to fr: friday
# fri-f: friday
# fri - f: friday
# fri to f: friday
# friday-f: friday
# friday - f: friday
# friday to f: friday
# fr-fri: friday
# fr - fri: friday
# fr to fri: friday
# fr-friday: friday
# fr - friday: friday
# fr to friday: friday
# fr-fr: friday
# fr - fr: friday
# fr to fr: friday
# fr-f: friday
# fr - f: friday
# fr to f: friday
# f-fri: friday
# f - fri: friday
# f to fri: friday
# f-friday: friday
# f - friday: friday
# f to friday: friday
# f-fr: friday
# f - fr: friday
# f to fr: friday
# f-f: friday
# f - f: friday
# f to f: friday
# friday-saturday: friday, saturday
# friday - saturday: friday, saturday
# friday to saturday: friday, saturday
# fri-sat: friday, saturday
# fri - sat: friday, saturday
# fri to sat: friday, saturday
# fri-saturday: friday, saturday
# fri - saturday: friday, saturday
# fri to saturday: friday, saturday
# friday-sat: friday, saturday
# friday - sat: friday, saturday
# friday to sat: friday, saturday
# fri-sa: friday, saturday
# fri - sa: friday, saturday
# fri to sa: friday, saturday
# friday-sa: friday, saturday
# friday - sa: friday, saturday
# friday to sa: friday, saturday
# fri-s: friday, saturday
# fri - s: friday, saturday
# fri to s: friday, saturday
# friday-s: friday, saturday
# friday - s: friday, saturday
# friday to s: friday, saturday
# fr-sat: friday, saturday
# fr - sat: friday, saturday
# fr to sat: friday, saturday
# fr-saturday: friday, saturday
# fr - saturday: friday, saturday
# fr to saturday: friday, saturday
# fr-sa: friday, saturday
# fr - sa: friday, saturday
# fr to sa: friday, saturday
# fr-s: friday, saturday
# fr - s: friday, saturday
# fr to s: friday, saturday
# f-sat: friday, saturday
# f - sat: friday, saturday
# f to sat: friday, saturday
# f-saturday: friday, saturday
# f - saturday: friday, saturday
# f to saturday: friday, saturday
# f-sa: friday, saturday
# f - sa: friday, saturday
# f to sa: friday, saturday
# f-s: friday, saturday
# f - s: friday, saturday
# f to s: friday, saturday
# friday-sunday: friday, saturday, sunday
# friday - sunday: friday, saturday, sunday
# friday to sunday: friday, saturday, sunday
# fri-sun: friday, saturday, sunday
# fri - sun: friday, saturday, sunday
# fri to sun: friday, saturday, sunday
# fri-sunday: friday, saturday, sunday
# fri - sunday: friday, saturday, sunday
# fri to sunday: friday, saturday, sunday
# friday-sun: friday, saturday, sunday
# friday - sun: friday, saturday, sunday
# friday to sun: friday, saturday, sunday
# fri-su: friday, saturday, sunday
# fri - su: friday, saturday, sunday
# fri to su: friday, saturday, sunday
# friday-su: friday, saturday, sunday
# friday - su: friday, saturday, sunday
# friday to su: friday, saturday, sunday
# fr-sun: friday, saturday, sunday
# fr - sun: friday, saturday, sunday
# fr to sun: friday, saturday, sunday
# fr-sunday: friday, saturday, sunday
# fr - sunday: friday, saturday, sunday
# fr to sunday: friday, saturday, sunday
# fr-su: friday, saturday, sunday
# fr - su: friday, saturday, sunday
# fr to su: friday, saturday, sunday
# f-sun: friday, saturday, sunday
# f - sun: friday, saturday, sunday
# f to sun: friday, saturday, sunday
# f-sunday: friday, saturday, sunday
# f - sunday: friday, saturday, sunday
# f to sunday: friday, saturday, sunday
# f-su: friday, saturday, sunday
# f - su: friday, saturday, sunday
# f to su: friday, saturday, sunday
# saturday-saturday: saturday
# saturday - saturday: saturday
# saturday to saturday: saturday
# sat-sat: saturday
# sat - sat: saturday
# sat to sat: saturday
# sat-saturday: saturday
# sat - saturday: saturday
# sat to saturday: saturday
# saturday-sat: saturday
# saturday - sat: saturday
# saturday to sat: saturday
# sat-sa: saturday
# sat - sa: saturday
# sat to sa: saturday
# saturday-sa: saturday
# saturday - sa: saturday
# saturday to sa: saturday
# sat-s: saturday
# sat - s: saturday
# sat to s: saturday
# saturday-s: saturday
# saturday - s: saturday
# saturday to s: saturday
# sa-sat: saturday
# sa - sat: saturday
# sa to sat: saturday
# sa-saturday: saturday
# sa - saturday: saturday
# sa to saturday: saturday
# sa-sa: saturday
# sa - sa: saturday
# sa to sa: saturday
# sa-s: saturday
# sa - s: saturday
# sa to s: saturday
# s-sat: saturday
# s - sat: saturday
# s to sat: saturday
# s-saturday: saturday
# s - saturday: saturday
# s to saturday: saturday
# s-sa: saturday
# s - sa: saturday
# s to sa: saturday
# s-s: saturday
# s - s: saturday
# s to s: saturday
# saturday-sunday: saturday, sunday
# saturday - sunday: saturday, sunday
# saturday to sunday: saturday, sunday
# sat - sun: saturday, sunday
# sat to sun: saturday, sunday
# sat-sunday: saturday, sunday
# sat - sunday: saturday, sunday
# sat to sunday: saturday, sunday
# saturday-sun: saturday, sunday
# saturday - sun: saturday, sunday
# saturday to sun: saturday, sunday
# sat-su: saturday, sunday
# sat - su: saturday, sunday
# sat to su: saturday, sunday
# saturday-su: saturday, sunday
# saturday - su: saturday, sunday
# saturday to su: saturday, sunday
# sa-sun: saturday, sunday
# sa - sun: saturday, sunday
# sa to sun: saturday, sunday
# sa-sunday: saturday, sunday
# sa - sunday: saturday, sunday
# sa to sunday: saturday, sunday
# sa-su: saturday, sunday
# sa - su: saturday, sunday
# sa to su: saturday, sunday
# s-sun: saturday, sunday
# s - sun: saturday, sunday
# s to sun: saturday, sunday
# s-sunday: saturday, sunday
# s - sunday: saturday, sunday
# s to sunday: saturday, sunday
# s-su: saturday, sunday
# s - su: saturday, sunday
# s to su: saturday, sunday
# sunday-sunday: sunday
# sunday - sunday: sunday
# sunday to sunday: sunday
# sun-sun: sunday
# sun - sun: sunday
# sun to sun: sunday
# sun-sunday: sunday
# sun - sunday: sunday
# sun to sunday: sunday
# sunday-sun: sunday
# sunday - sun: sunday
# sunday to sun: sunday
# sun-su: sunday
# sun - su: sunday
# sun to su: sunday
# sunday-su: sunday
# sunday - su: sunday
# sunday to su: sunday
# su-sun: sunday
# su - sun: sunday
# su to sun: sunday
# su-sunday: sunday
# su - sunday: sunday
# su to sunday: sunday
# su-su: sunday
# su - su: sunday
# su to su: sunday

# %%
import pandas as pd
import re
import json

# Load the data from the specified Excel file and sheet
file_path = '/Users/rsiddiq2/Documents/FBCENC Test.xlsx'
sheet1_data = pd.ExcelFile(file_path).parse('Sheet1')

# Rename the columns for convenience (if necessary)
sheet1_data.rename(columns=lambda x: x.strip(), inplace=True)  # Removing any leading/trailing whitespace

# Update column names to match your actual file's columns
agency_no_column = 'Parent Agency No.'
agency_name_column = 'Agency_Name' if 'Agency_Name' in sheet1_data.columns else 'Agency Name'
delivery_info_column = 'Delivery Info.' if 'Delivery Info.' in sheet1_data.columns else 'Delivery Information'

# Function to normalize time format
def normalize_time(hour, minute, am_pm,is_end_time=False):
    # If minutes are not provided, set them to "00"
   
    if not minute:
        minute = "00"
    if am_pm in ['a', 'p']:
        am_pm = f"{am_pm}m"
    '''
    # If AM/PM is not provided, default to "AM" for start times and "PM" for end times
    if not am_pm:
        am_pm = "am"  # Assuming AM for start times
    
    if not is_end_time and int(hour) >= 12 and int(hour) <=6 and am_pm == "am":
        am_pm = "pm"
   
    if is_end_time and am_pm == "am" and int(hour) >= 1 : 
        am_pm = "pm"
    '''
    if not am_pm:
        if int(hour) ==12:
            am_pm="pm"
        elif int(hour) >6 and int(hour)<12:
            am_pm="am"
        else:
            am_pm = "pm"
    # Return the time in the format "HH:MM AM/PM"
    return f"{hour}:{minute} {am_pm}"
    
# Function to normalize the days and times
def normalize_days_and_times(text):
    # Convert text to lowercase for consistent matching
    text = text.lower()

    # Replace specific abbreviations like "MWF" or "Mon-Fri"
    '''
    day_abbreviation_mapping = {
        'mwf': 'monday, wednesday, friday',
        'tth': 'tuesday, thursday',
        'mon-fri': 'monday, tuesday, wednesday, thursday, friday',
        'mon - fri':'monday, tuesday, wednesday, thursday, friday',
        'mon-sat': 'monday, tuesday, wednesday, thursday, friday, saturday',
        'm-f': 'monday, tuesday, wednesday, thursday, friday',
        'sat-sun': 'saturday, sunday',
        'tue-thu': 'tuesday, wednesday, thursday',
        'monday-friday':'monday, tuesday, wednesday, thursday, friday',
        'monday-thursday':'monday, tuesday, wednesday, thursday',
        'm-th' : 'monday, tuesday, wednesday, thursday',

    }
    '''
    for abbr, days in day_abbreviation_mapping.items():
        text = re.sub(r'\b' + re.escape(abbr) + r'\b', days, text)

    # Replace individual day abbreviations with full names
    day_mapping = {
        'mon': 'monday', 'tue': 'tuesday', 'wed': 'wednesday', 'thu': 'thursday',
        'fri': 'friday', 'sat': 'saturday', 'sun': 'sunday',
        'm': 'monday', 'w': 'wednesday','t': 'tuesday', 'f': 'friday',
        'sa': 'saturday', 'su' : 'sunday','fr':'friday', 'th': 'thursday',
        'thur':'thursday',
        'thurs':'thursday','tues':'tuesday'
    }
    for short, full in day_mapping.items():
        text = re.sub(r'\b' + re.escape(short) + r'\b', full, text, flags=re.IGNORECASE)

    # Replace plural days like "Thursdays" with singular form "Thursday"
    text = re.sub(r'\b(.*?s)\b', lambda m: m.group(1)[:-1], text)
    
    # Normalize time ranges in the format "8-5 pm" or "8 am - 5 pm"
    text = re.sub(
        r'(\d{1,2}):(\d{2})(a|p)\s*-\s*(\d{1,2}):(\d{2})(a|p)',
        lambda m: f"{normalize_time(m.group(1), m.group(2), m.group(3))} - {normalize_time(m.group(4), m.group(5), m.group(6), is_end_time=True)}",
        text, flags=re.IGNORECASE
    )

    # Handle patterns like "6a-6p" (without minutes)
    text = re.sub(
        r'(\d{1,2})(a|p)\s*-\s*(\d{1,2})(a|p)',
        lambda m: f"{normalize_time(m.group(1), '00', m.group(2))} - {normalize_time(m.group(3), '00', m.group(4), is_end_time=True)}",
        text, flags=re.IGNORECASE
    )

    # Normalize time ranges like "8-5 pm" or "8 am - 5 pm"
    text = re.sub(
        r'(\d{1,2})(?::(\d{2}))?\s*(am|pm)?\s*-\s*(\d{1,2})(?::(\d{2}))?\s*(am|pm)?',
        lambda m: f"{normalize_time(m.group(1), m.group(2), m.group(3))} - {normalize_time(m.group(4), m.group(5), m.group(6), is_end_time=True)}",
        text, flags=re.IGNORECASE
    )
    return text

# Apply the normalization function to the 'Delivery Info.' column
sheet1_data['Normalized_Delivery_Info'] = sheet1_data[delivery_info_column].apply(normalize_days_and_times)

def standardize_delivery_info(normalized_text):
    standardized_info = []

    # Define patterns for days, weeks, and times
    #day_pattern = r"(Monday|Tuesday|Wednesday|Thursday|Friday|Saturday|Sunday)"
    day_pattern = r"(monday|tuesday|wednesday|thursday|friday|saturday|sunday)"
    week_pattern = r"(\d+(?:st|nd|rd|th))\s*(?:week)?"
    time_pattern = r"(\d{1,2}:\d{2}\s*(?:AM|PM)?(?:\s*[-to]+\s*\d{1,2}:\d{2}\s*(?:AM|PM)?)?)"

    # Split the text into parts for analysis
    parts = re.split(r'[;,]', normalized_text)

    current_days = []
    current_weeks = []
    start_time = "Unknown"
    end_time = "Unknown"

    # Iterate over each part to identify days, weeks, and times in sequence
    for part in parts:
        part = part.strip()
        #print(f"Processing part: {part}")  # Debugging statement to see the current part being processed

        # Extract weeks if mentioned
        weeks = re.findall(week_pattern, part, re.IGNORECASE)
        if weeks:
            current_weeks = weeks
            
        # Extract days
        days = re.findall(day_pattern, part)
        if days:
            current_days.extend(days)

        # Extract times if present
        time_match = re.search(time_pattern, part, re.IGNORECASE)
        if time_match:
            time_str = time_match.group().strip()
            #print(standardized_info)
            # Handle time ranges
            if '-' in time_str or 'to' in time_str:
                start_time, end_time = map(str.strip, re.split(r'-|to', time_str, flags=re.IGNORECASE))
            else:
                start_time = time_str
                end_time = time_str
                
            # Assign the found times to all current days
            if current_days:
                
                for day in current_days:
                    standardized_info.append({
                        "Day": day,
                        "Opening_Hour": start_time,
                        "Closing_Hour": end_time,
                        "Week": current_weeks if current_weeks else ["1", "2", "3", "4"]
                    })
                
                # Reset the current_days and current_weeks since we have assigned the times
                current_days = []
                current_weeks = []
                start_time = "Unknown"
                end_time = "Unknown"

    # If there are remaining days without assigned times, add them with "Unknown"
    if current_days:
        for day in current_days:
            standardized_info.append({
                "Day": day,
                "Opening_Hour": "Unknown",
                "Closing_Hour": "Unknown",
                "Week": current_weeks if current_weeks else ["1", "2", "3", "4"]
            })
    
    return json.dumps(standardized_info, indent=2)

# Apply standardization to the 'Normalized_Delivery_Info' column
sheet1_data['Standardized_Delivery_Info'] = sheet1_data['Normalized_Delivery_Info'].apply(standardize_delivery_info)


# Print out the standardized delivery info for verification
#print(sheet1_data[['Parent Agency No.', 'Standardized_Delivery_Info']].head())

# %%
for n in (901,45,133,55,66,47):
    

    
    
    
    
    #print(sheet1_data["Standardized_Delivery_Info_Set_1"][n])
    
    
    print("Original Text:",sheet1_data['Delivery Info.'][n])
    print("Normalized Text:",sheet1_data['Normalized_Delivery_Info'][n])
    print(sheet1_data['Standardized_Delivery_Info'][n])
# Out:
# Original Text: Tuesdays 8:30-11am
# Normalized Text: tuesday 8:30 am - 11:00 am
# [
#   {
#     "Day": "tuesday",
#     "Opening_Hour": "8:30 am",
#     "Closing_Hour": "11:00 am",
#     "Week": [
#       "1",
#       "2",
#       "3",
#       "4"
#     ]
#   }
# ]
# Original Text: 24/7
# Normalized Text: 24/7
# []
# Original Text: DD 1st & 3rd Thurs 9:30am-1:30pm; pantry 2nd & 4th Wed 6-7pm
# Normalized Text: dd 1st & 3rd thursday 9:30 am - 1:30 pm; pantry 2nd & 4th wednesday 6:00 pm - 7:00 pm
# [
#   {
#     "Day": "thursday",
#     "Opening_Hour": "9:30 am",
#     "Closing_Hour": "1:30 pm",
#     "Week": [
#       "1st",
#       "3rd"
#     ]
#   },
#   {
#     "Day": "wednesday",
#     "Opening_Hour": "6:00 pm",
#     "Closing_Hour": "7:00 pm",
#     "Week": [
#       "2nd",
#       "4th"
#     ]
#   }
# ]
# Original Text: Wednesdays 9am-1pm
# Normalized Text: wednesday 9:00 am - 1:00 pm
# [
#   {
#     "Day": "wednesday",
#     "Opening_Hour": "9:00 am",
#     "Closing_Hour": "1:00 pm",
#     "Week": [
#       "1",
#       "2",
#       "3",
#       "4"
#     ]
#   }
# ]
# Original Text: M-F 8-5
# Normalized Text: monday, tuesday, wednesday, thursday, friday 8:00 am - 5:00 pm
# [
#   {
#     "Day": "monday",
#     "Opening_Hour": "8:00 am",
#     "Closing_Hour": "5:00 pm",
#     "Week": [
#       "1",
#       "2",
#       "3",
#       "4"
#     ]
#   },
#   {
#     "Day": "tuesday",
#     "Opening_Hour": "8:00 am",
#     "Closing_Hour": "5:00 pm",
#     "Week": [
#       "1",
#       "2",
#       "3",
#       "4"
#     ]
#   },
#   {
#     "Day": "wednesday",
#     "Opening_Hour": "8:00 am",
#     "Closing_Hour": "5:00 pm",
#     "Week": [
#       "1",
#       "2",
#       "3",
#       "4"
#     ]
#   },
#   {
#     "Day": "thursday",
#     "Opening_Hour": "8:00 am",
#     "Closing_Hour": "5:00 pm",
#     "Week": [
#       "1",
#       "2",
#       "3",
#       "4"
#     ]
#   },
#   {
#     "Day": "friday",
#     "Opening_Hour": "8:00 am",
#     "Closing_Hour": "5:00 pm",
#     "Week": [
#       "1",
#       "2",
#       "3",
#       "4"
#     ]
#   }
# ]
# Original Text: M-F 9-2
# Normalized Text: monday, tuesday, wednesday, thursday, friday 9:00 am - 2:00 pm
# [
#   {
#     "Day": "monday",
#     "Opening_Hour": "9:00 am",
#     "Closing_Hour": "2:00 pm",
#     "Week": [
#       "1",
#       "2",
#       "3",
#       "4"
#     ]
#   },
#   {
#     "Day": "tuesday",
#     "Opening_Hour": "9:00 am",
#     "Closing_Hour": "2:00 pm",
#     "Week": [
#       "1",
#       "2",
#       "3",
#       "4"
#     ]
#   },
#   {
#     "Day": "wednesday",
#     "Opening_Hour": "9:00 am",
#     "Closing_Hour": "2:00 pm",
#     "Week": [
#       "1",
#       "2",
#       "3",
#       "4"
#     ]
#   },
#   {
#     "Day": "thursday",
#     "Opening_Hour": "9:00 am",
#     "Closing_Hour": "2:00 pm",
#     "Week": [
#       "1",
#       "2",
#       "3",
#       "4"
#     ]
#   },
#   {
#     "Day": "friday",
#     "Opening_Hour": "9:00 am",
#     "Closing_Hour": "2:00 pm",
#     "Week": [
#       "1",
#       "2",
#       "3",
#       "4"
#     ]
#   }
# ]

# %%
import pandas as pd
import json

# Load the data from the specified Excel file and sheet
file_path = '/Users/rsiddiq2/Documents/FBCENC Test.xlsx'
#sheet1_data = pd.ExcelFile(file_path).parse('Sheet1')

# Function to process the JSON data in the 'Standardized_Delivery_Info' column
def process_json_in_column(df, json_column):
    new_rows = []

    # Loop through each row in the dataframe
    for index, row in df.iterrows():
        try:
            # Load the JSON data from the column (assuming it's in string format)
            json_data = json.loads(row[json_column])
            
            # Loop through each day entry in the JSON data
            for entry in json_data:
                day = entry["Day"]
                opening_hour = entry["Opening_Hour"]
                closing_hour = entry["Closing_Hour"]
                weeks = entry["Week"]
                
                # Create a new row for each week for the given day
                for week in weeks:
                    # Create a new row with the original columns and the extracted day/week info
                    new_row = {
                        "Parent Agency No.": row["Parent Agency No."],
                        "No.": row["No."],
                        "Name": row["Name"],
                        "Parent Agency No..1": row["Parent Agency No..1"],
                        "Name 2": row["Name 2"],
                        "Address": row["Address"],
                        "City": row["City"],
                        "State": row["State"],
                        "ZIP Code": row["ZIP Code"],
                        "Day": day,
                        "Opening_Hour": opening_hour,
                        "Closing_Hour": closing_hour,
                        "Week": week
                    }
                    new_rows.append(new_row)

        except Exception as e:
            print(f"Error processing row {index}: {e}")
    
    # Create a new DataFrame with the new rows
    return pd.DataFrame(new_rows)

# Apply the function to process the JSON column
expanded_df = process_json_in_column(sheet1_data, 'Standardized_Delivery_Info')

# Now 'expanded_df' contains the new rows with the additional info
print(expanded_df.head())  # Preview the first few rows
# Out:
#   Parent Agency No.      No.                  Name Parent Agency No..1 Name 2  \
# 0             D1001  D1001FP  ACTS of Vance County               D1001    NaN
# 1             D1001  D1001FP  ACTS of Vance County               D1001    NaN
# 2             D1001  D1001FP  ACTS of Vance County               D1001    NaN
# 3             D1001  D1001FP  ACTS of Vance County               D1001    NaN
# 4             D1001  D1001FP  ACTS of Vance County               D1001    NaN
#
#             Address       City State ZIP Code      Day Opening_Hour  \
# 0  201 S William St  Henderson    NC    27536   monday      8:30 am
# 1  201 S William St  Henderson    NC    27536   monday      8:30 am
# 2  201 S William St  Henderson    NC    27536   monday      8:30 am
# 3  201 S William St  Henderson    NC    27536   monday      8:30 am
# 4  201 S William St  Henderson    NC    27536  tuesday      8:30 am
#
#   Closing_Hour Week
# 0     11:30 am    1
# 1     11:30 am    2
# 2     11:30 am    3
# 3     11:30 am    4
# 4     11:30 am    1

# %%
expanded_df.head(40)
# Out:
#    Parent Agency No.      No.                  Name Parent Agency No..1  \
# 0              D1001  D1001FP  ACTS of Vance County               D1001
# 1              D1001  D1001FP  ACTS of Vance County               D1001
# 2              D1001  D1001FP  ACTS of Vance County               D1001
# 3              D1001  D1001FP  ACTS of Vance County               D1001
# 4              D1001  D1001FP  ACTS of Vance County               D1001
# 5              D1001  D1001FP  ACTS of Vance County               D1001
# 6              D1001  D1001FP  ACTS of Vance County               D1001
# 7              D1001  D1001FP  ACTS of Vance County               D1001
# 8              D1001  D1001FP  ACTS of Vance County               D1001
# 9              D1001  D1001FP  ACTS of Vance County               D1001
# 10             D1001  D1001FP  ACTS of Vance County               D1001
# 11             D1001  D1001FP  ACTS of Vance County               D1001
# 12             D1001  D1001FP  ACTS of Vance County               D1001
# 13             D1001  D1001FP  ACTS of Vance County               D1001
# 14             D1001  D1001FP  ACTS of Vance County               D1001
# 15             D1001  D1001FP  ACTS of Vance County               D1001
# 16             D1001  D1001FP  ACTS of Vance County               D1001
# 17             D1001  D1001FP  ACTS of Vance County               D1001
# 18             D1001  D1001FP  ACTS of Vance County               D1001
# 19             D1001  D1001FP  ACTS of Vance County               D1001
# 20             D1001  D1001SK  ACTS of Vance County               D1001
# 21             D1001  D1001SK  ACTS of Vance County               D1001
# 22             D1001  D1001SK  ACTS of Vance County               D1001
# 23             D1001  D1001SK  ACTS of Vance County               D1001
# 24             D1001  D1001SK  ACTS of Vance County               D1001
# 25             D1001  D1001SK  ACTS of Vance County               D1001
# 26             D1001  D1001SK  ACTS of Vance County               D1001
# 27             D1001  D1001SK  ACTS of Vance County               D1001
# 28             D1001  D1001SK  ACTS of Vance County               D1001
# 29             D1001  D1001SK  ACTS of Vance County               D1001
# 30             D1001  D1001SK  ACTS of Vance County               D1001
# 31             D1001  D1001SK  ACTS of Vance County               D1001
# 32             D1001  D1001SK  ACTS of Vance County               D1001
# 33             D1001  D1001SK  ACTS of Vance County               D1001
# 34             D1001  D1001SK  ACTS of Vance County               D1001
# 35             D1001  D1001SK  ACTS of Vance County               D1001
# 36             D1001  D1001SK  ACTS of Vance County               D1001
# 37             D1001  D1001SK  ACTS of Vance County               D1001
# 38             D1001  D1001SK  ACTS of Vance County               D1001
# 39             D1001  D1001SK  ACTS of Vance County               D1001
#
#    Name 2           Address       City State ZIP Code        Day Opening_Hour  \
# 0     NaN  201 S William St  Henderson    NC    27536     monday      8:30 am
# 1     NaN  201 S William St  Henderson    NC    27536     monday      8:30 am
# 2     NaN  201 S William St  Henderson    NC    27536     monday      8:30 am
# 3     NaN  201 S William St  Henderson    NC    27536     monday      8:30 am
# 4     NaN  201 S William St  Henderson    NC    27536    tuesday      8:30 am
# 5     NaN  201 S William St  Henderson    NC    27536    tuesday      8:30 am
# 6     NaN  201 S William St  Henderson    NC    27536    tuesday      8:30 am
# 7     NaN  201 S William St  Henderson    NC    27536    tuesday      8:30 am
# 8     NaN  201 S William St  Henderson    NC    27536  wednesday      8:30 am
# 9     NaN  201 S William St  Henderson    NC    27536  wednesday      8:30 am
# 10    NaN  201 S William St  Henderson    NC    27536  wednesday      8:30 am
# 11    NaN  201 S William St  Henderson    NC    27536  wednesday      8:30 am
# 12    NaN  201 S William St  Henderson    NC    27536   thursday      8:30 am
# 13    NaN  201 S William St  Henderson    NC    27536   thursday      8:30 am
# 14    NaN  201 S William St  Henderson    NC    27536   thursday      8:30 am
# 15    NaN  201 S William St  Henderson    NC    27536   thursday      8:30 am
# 16    NaN  201 S William St  Henderson    NC    27536     friday      8:30 am
# 17    NaN  201 S William St  Henderson    NC    27536     friday      8:30 am
# 18    NaN  201 S William St  Henderson    NC    27536     friday      8:30 am
# 19    NaN  201 S William St  Henderson    NC    27536     friday      8:30 am
# 20    NaN  201 S William St  Henderson    NC    27536     monday     10:30 am
# 21    NaN  201 S William St  Henderson    NC    27536     monday     10:30 am
# 22    NaN  201 S William St  Henderson    NC    27536     monday     10:30 am
# 23    NaN  201 S William St  Henderson    NC    27536     monday     10:30 am
# 24    NaN  201 S William St  Henderson    NC    27536    tuesday     10:30 am
# 25    NaN  201 S William St  Henderson    NC    27536    tuesday     10:30 am
# 26    NaN  201 S William St  Henderson    NC    27536    tuesday     10:30 am
# 27    NaN  201 S William St  Henderson    NC    27536    tuesday     10:30 am
# 28    NaN  201 S William St  Henderson    NC    27536  wednesday     10:30 am
# 29    NaN  201 S William St  Henderson    NC    27536  wednesday     10:30 am
# 30    NaN  201 S William St  Henderson    NC    27536  wednesday     10:30 am
# 31    NaN  201 S William St  Henderson    NC    27536  wednesday     10:30 am
# 32    NaN  201 S William St  Henderson    NC    27536   thursday     10:30 am
# 33    NaN  201 S William St  Henderson    NC    27536   thursday     10:30 am
# 34    NaN  201 S William St  Henderson    NC    27536   thursday     10:30 am
# 35    NaN  201 S William St  Henderson    NC    27536   thursday     10:30 am
# 36    NaN  201 S William St  Henderson    NC    27536     friday     10:30 am
# 37    NaN  201 S William St  Henderson    NC    27536     friday     10:30 am
# 38    NaN  201 S William St  Henderson    NC    27536     friday     10:30 am
# 39    NaN  201 S William St  Henderson    NC    27536     friday     10:30 am
#
#    Closing_Hour Week
# 0      11:30 am    1
# 1      11:30 am    2
# 2      11:30 am    3
# 3      11:30 am    4
# 4      11:30 am    1
# 5      11:30 am    2
# 6      11:30 am    3
# 7      11:30 am    4
# 8      11:30 am    1
# 9      11:30 am    2
# 10     11:30 am    3
# 11     11:30 am    4
# 12     11:30 am    1
# 13     11:30 am    2
# 14     11:30 am    3
# 15     11:30 am    4
# 16     11:30 am    1
# 17     11:30 am    2
# 18     11:30 am    3
# 19     11:30 am    4
# 20     11:15 am    1
# 21     11:15 am    2
# 22     11:15 am    3
# 23     11:15 am    4
# 24     11:15 am    1
# 25     11:15 am    2
# 26     11:15 am    3
# 27     11:15 am    4
# 28     11:15 am    1
# 29     11:15 am    2
# 30     11:15 am    3
# 31     11:15 am    4
# 32     11:15 am    1
# 33     11:15 am    2
# 34     11:15 am    3
# 35     11:15 am    4
# 36     11:15 am    1
# 37     11:15 am    2
# 38     11:15 am    3
# 39     11:15 am    4

# %%
import pandas as pd
import re
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import DataLoader, TensorDataset
import torch.nn as nn
import torch.optim as optim

file_path = '/Users/rsiddiq2/Documents/FBCENC Test.xlsx'
sheet1_data = pd.ExcelFile(file_path).parse('Sheet1')

sheet1_data.rename(columns=lambda x: x.strip(), inplace=True)
agency_no_column = 'Parent Agency No.'
delivery_info_column = 'Delivery Info.'

# Prepare data for training
rows = sheet1_data[delivery_info_column].dropna().tolist()
labels = ['valid' if 'mon' in row.lower() or 'fri' in row.lower() else 'invalid' for row in rows]

# Split data into train and test sets
train_texts, test_texts, train_labels, test_labels = train_test_split(rows[:150], labels[:150], test_size=0.2, random_state=42)

# Load pre-trained tokenizer
model_name = 'bert-base-uncased'
tokenizer = AutoTokenizer.from_pretrained(model_name)

train_encodings = tokenizer(train_texts, truncation=True, padding=True, max_length=128)
test_encodings = tokenizer(test_texts, truncation=True, padding=True, max_length=128)

label_encoder = LabelEncoder()
train_labels = label_encoder.fit_transform(train_labels)
test_labels = label_encoder.transform(test_labels)

# Create PyTorch datasets
train_dataset = TensorDataset(
    torch.tensor(train_encodings['input_ids']),
    torch.tensor(train_encodings['attention_mask']),
    torch.tensor(train_labels)
)

test_dataset = TensorDataset(
    torch.tensor(test_encodings['input_ids']),
    torch.tensor(test_encodings['attention_mask']),
    torch.tensor(test_labels)
)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

# Define a simple model using BERT
class BERTClassifier(nn.Module):
    def __init__(self, model_name, num_labels):
        super(BERTClassifier, self).__init__()
        self.bert = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=num_labels)

    def forward(self, input_ids, attention_mask):
        output = self.bert(input_ids, attention_mask=attention_mask)
        return output.logits

# Initialize model, loss function, and optimizer
model = BERTClassifier(model_name, num_labels=2)
optimizer = optim.AdamW(model.parameters(), lr=5e-5)
loss_fn = nn.CrossEntropyLoss()

# Training loop
for epoch in range(3):
    model.train()
    for batch in train_loader:
        input_ids, attention_mask, labels = batch
        optimizer.zero_grad()
        outputs = model(input_ids, attention_mask)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()

# Normalize time formatting

def normalize_time(hour, minute, am_pm,is_end_time=False):
    if not minute:
        minute = "00"
    if am_pm in ['a', 'p']:
        am_pm = f"{am_pm}m"
    if not am_pm:
        if int(hour) ==12:
            am_pm="pm"
        elif int(hour) >6 and int(hour)<12:
            am_pm="am"
        else:
            am_pm = "pm"
    return f"{hour}:{minute} {am_pm}"

# Normalize days and times

def normalize_days_and_times(text):
    text = text.lower()

    text = re.sub(
        r'(\d{1,2})(?::(\d{2}))?\s*(am|pm)?\s*-\s*(\d{1,2})(?::(\d{2}))?\s*(am|pm)?',
        lambda m: f"{normalize_time(m.group(1), m.group(2), m.group(3))} - {normalize_time(m.group(4), m.group(5), m.group(6), is_end_time=True)}",
        text, flags=re.IGNORECASE
    )

    # Use trained AI model to classify and validate
    encodings = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128)
    input_ids = encodings['input_ids']
    attention_mask = encodings['attention_mask']
    outputs = model(input_ids, attention_mask)
    prediction = torch.argmax(outputs, dim=1)

    if prediction.item() == 1:
        text = f"Valid: {text}"
    else:
        text = f"Invalid: {text}"
    
    return text

sheet1_data['Normalized_Delivery_Info'] = sheet1_data[delivery_info_column].apply(normalize_days_and_times)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
sheet1_data
# Out:
#     Parent Agency No.      No.  \
# 0               D1001  D1001FP
# 1               D1001  D1001SK
# 2               D1002  D1002GH
# 3               D1005  D1005FP
# 4               D1005  D1005TF
# ..                ...      ...
# 931             W1144  W1144FP
# 932             W1147  W1147FP
# 933             W1152  W1152DV
# 934             W1160  W1160DD
# 935             W1160  W1160SH
#
#                                                Name Parent Agency No..1  \
# 0                              ACTS of Vance County               D1001
# 1                              ACTS of Vance County               D1001
# 2                Alliance Rehabilitative Care - Men               D1002
# 3                         Alston Chapel United Holy               D1005
# 4                         Alston Chapel United Holy               D1005
# ..                                              ...                 ...
# 931                        CR Resource Center Inc.                W1144
# 932            Liberty Baptist Church of Wilmington               W1147
# 933            Domestic Violence Shelter & Services               W1152
# 934  The Healing Place of New Hanover County, Inc.                W1160
# 935   The Healing Place of New Hanover County, Inc.               W1160
#
#             Name 2                    Address           City State ZIP Code  \
# 0              NaN           201 S William St      Henderson    NC    27536
# 1              NaN           201 S William St      Henderson    NC    27536
# 2    Halfway House        1020 County Home Rd      Henderson    NC    27536
# 3           Church      1832 Alston Chapel Rd      Pittsboro    NC    27312
# 4           Church      1832 Alston Chapel Rd      Pittsboro    NC    27312
# ..             ...                        ...            ...   ...      ...
# 931            NaN            107 Mt. Zion St  Lake Waccamaw    NC    28450
# 932            NaN             7957 Market St     Wilmington    NC    28411
# 933            NaN              Confidential      Wilmington    NC    28405
# 934            NaN  1000 Medical Center Drive     Wilmington    NC    28401
# 935            NaN  1000 Medical Center Drive     Wilmington    NC    28401
#
#     FBC County Code  ... Monitoring within the last six month   FST Date  \
# 0             VANCE  ...                                   No 2023-09-07
# 1             VANCE  ...                                   No 2023-09-07
# 2             VANCE  ...                                   No 2026-08-22
# 3           CHATHAM  ...                                   No 2023-09-03
# 4           CHATHAM  ...                                   No 2023-08-24
# ..              ...  ...                                  ...        ...
# 931        COLUMBUS  ...                                   No 2023-03-01
# 932      NEWHANOVER  ...                                  NaN 2023-12-15
# 933      NEWHANOVER  ...                                  NaN 2022-10-28
# 934      NEWHANOVER  ...                                  NaN 2025-07-13
# 935      NEWHANOVER  ...                                  NaN 2026-07-13
#
#     FST done in last six months Monitoring Expiration Date  \
# 0                            No                 2019-08-01
# 1                            No                 2020-08-04
# 2                           Yes                 2020-11-06
# 3                            No                 2020-11-18
# 4                            No                 2020-11-20
# ..                          ...                        ...
# 931                          No                 2025-07-07
# 932                          No                        NaT
# 933                          No                        NaT
# 934                         Yes                        NaT
# 935                         Yes                        NaT
#
#     Food Safety Training Exp. Date UNC Activity Status Location Code  \
# 0                       2025-02-28              ACTIVE             D
# 1                       2025-02-28              ACTIVE             D
# 2                       2028-02-13              ACTIVE             D
# 3                       2025-02-24              ACTIVE             D
# 4                       2025-02-14              ACTIVE             D
# ..                             ...                 ...           ...
# 931                     2024-08-22              ACTIVE             W
# 932                     2025-06-07              ACTIVE             W
# 933                     2024-04-20              ACTIVE             W
# 934                     2027-01-04              ACTIVE             W
# 935                     2028-01-04              ACTIVE             W
#
#     FBC Agency Category Code  \
# 0                 FOODPANTRY
# 1                 SOUP KITCH
# 2                 GROUP HOME
# 3                 FOODPANTRY
# 4                      TEFAP
# ..                       ...
# 931               FOODPANTRY
# 932               FOODPANTRY
# 933                       DV
# 934               DIRECT DST
# 935                  SHELTER
#
#                                         Delivery Info.  \
# 0    Mon-Fri 8:30-11:30am for food assistance; must...
# 1                         Monday-Friday, 10:30-11:15am
# 2                                                 24/7
# 3    MWF 12:45-1:30pm; 3rd Wednesday (Food Bags); S...
# 4    MWF 12:45-1:30pm; 3rd Wednesday (Food Bags); S...
# ..                                                 ...
# 931                            Monday & Tuesday 1-3pm
# 932                         1st and 3rd Mondays 1-3pm
# 933                             Monday-Friday 9am-5pm
# 934   2nd and 4th Monday 3:30-5pm while supplies last
# 935                                               24/7
#
#                               Normalized_Delivery_Info
# 0                                      Invalid: friday
# 1                                      Invalid: friday
# 2                                        Invalid: 24/7
# 3                                     Valid: wednesday
# 4                                     Valid: wednesday
# ..                                                 ...
# 931         Valid: monday & tuesday 1:00 pm - 3:00 pm
# 932      Valid: 1st and 3rd mondays 1:00 pm - 3:00 pm
# 933            Valid: monday-friday 9:00 am - 5:00 pm
# 934  Invalid: 2nd and 4th monday 3:30 pm - 5:00 pm ...
# 935                                      Invalid: 24/7
#
# [936 rows x 25 columns]

# %%
import pandas as pd
import re
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

file_path = '/Users/rsiddiq2/Documents/FBCENC Test.xlsx'
sheet1_data = pd.ExcelFile(file_path).parse('Sheet1')

sheet1_data.rename(columns=lambda x: x.strip(), inplace=True)
agency_no_column = 'Parent Agency No.'
delivery_info_column = 'Delivery Info.'

# Load pre-trained model and tokenizer for sequence-to-sequence tasks
model_name = 't5-small'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Prepare training data
rows = sheet1_data[delivery_info_column].dropna().tolist()
training_rows = rows[:150]

# Function to preprocess text for training

def preprocess_training_data(rows):
    training_data = []
    for text in rows:
        text = text.lower()
        text = re.sub(r'\s+', ' ', text)  # Normalize spaces
        training_data.append(f"normalize: {text}")
    return training_data

# Generate training inputs
train_inputs = preprocess_training_data(training_rows)
train_labels = []
for row in training_rows:
    # Replace patterns to create labels for training
    label = re.sub(r'(\bmon\b|\bmon\b-day)', 'monday', row, flags=re.IGNORECASE)
    label = re.sub(r'(\btue\b|\btues\b)', 'tuesday', label, flags=re.IGNORECASE)
    label = re.sub(r'(\bwed\b|\bweds\b)', 'wednesday', label, flags=re.IGNORECASE)
    label = re.sub(r'(\bthu\b|\bthurs\b)', 'thursday', label, flags=re.IGNORECASE)
    label = re.sub(r'(\bfri\b)', 'friday', label, flags=re.IGNORECASE)
    label = re.sub(r'(\bsat\b)', 'saturday', label, flags=re.IGNORECASE)
    label = re.sub(r'(\bsun\b)', 'sunday', label, flags=re.IGNORECASE)
    label = re.sub(r'(\b\d{1,2}(?:[:.]\d{2})?\s*[ap]m\b)', lambda m: m.group().replace('.', ':'), label)
    train_labels.append(label)

# Tokenize inputs and labels
def tokenize_data(data):
    encodings = tokenizer(data, padding=True, truncation=True, return_tensors="pt", max_length=128)
    return encodings

train_encodings = tokenize_data(train_inputs)
label_encodings = tokenize_data(train_labels)

# Fine-tuning the model
optimizer = torch.optim.AdamW(model.parameters(), lr=5e-5)

for epoch in range(3):
    model.train()
    optimizer.zero_grad()
    outputs = model(input_ids=train_encodings['input_ids'], attention_mask=train_encodings['attention_mask'], labels=label_encodings['input_ids'])
    loss = outputs.loss
    loss.backward()
    optimizer.step()

# Generate normalized text using the fine-tuned model
def generate_normalized_text(text):
    input_text = f"normalize: {text.lower()}"
    inputs = tokenizer(input_text, return_tensors="pt", truncation=True, padding=True, max_length=128)
    outputs = model.generate(inputs['input_ids'], max_length=128, num_return_sequences=1)
    normalized_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return normalized_text

# Apply AI-based dictionary generation
sheet1_data['Normalized_Delivery_Info'] = sheet1_data[delivery_info_column].apply(generate_normalized_text)

# Print sample results
print(sheet1_data[['Parent Agency No.', 'Normalized_Delivery_Info']].head())
# Out:
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
#   Parent Agency No.                           Normalized_Delivery_Info
# 0             D1001  normalize: mon-fri 8:30-11:30am for food assis...
# 1             D1001  normalize normal normalize: monday-day, 10:30-...
# 2             D1002                                          24/7 24/7
# 3             D1005  at 12:45-1:30 pm; sundays 12:30-1 pm; sundays ...
# 4             D1005                  12:45-1:30 pm; sundays 12:30-1 pm

# %%
sheet1_data[['Parent Agency No.', 'Normalized_Delivery_Info']].head(40)
# Out:
#    Parent Agency No.                           Normalized_Delivery_Info
# 0              D1001  normalize: mon-fri 8:30-11:30am for food assis...
# 1              D1001  normalize normal normalize: monday-day, 10:30-...
# 2              D1002                                          24/7 24/7
# 3              D1005  at 12:45-1:30 pm; sundays 12:30-1 pm; sundays ...
# 4              D1005                  12:45-1:30 pm; sundays 12:30-1 pm
# 5              D1006  normalize: 2nd and 4th wednesday from 12:00pm ...
# 6              D1008                                                -pm
# 7              D1008                            normalize: mwf/9am-12pm
# 8              D1009    Normal normal: 2nd and 4th thursdays from 5-7pm
# 9              D1009                                Mon, wed, fri 3-6pm
# 10             D1011  a normal normal: saturday before 4th sunday; s...
# 11             D1013  Normalize: 1 & 3r tuesday and wednesday of eac...
# 12             D1014  normal normal normalize monday- monday-normal ...
# 13             D1015  Normalize: 4th saturday/month, 7am-9:00am and ...
# 14             D1015  Normalize: 4th saturday/month, 7am-9:00am und ...
# 15             D1018                  wednesday 10 de 10 10:00-mitmit 1
# 16             D1019  normal normalize: 3 friday/month, 9:30-11am, a...
# 17             D1019  Normal normal normalize: 3r friday/month 9:30 ...
# 18             D1020                           normalize: m-f 10:20-2pm
# 19             D1020            normalize m-f 10 m-m 10am m-f 10am-2pm;
# 20             D1021  normalize: 2 : 2 : 2nd, 4th thursdays, 4-4th t...
# 21             D1021  days, 4pm to 6pm to 6pm to 6pm: 2nd, 4th thurs...
# 22             D1022  Normalize: thursdays, 12-2pm; 2nd and 4th mond...
# 23             D1023        (Monday-friday, 9am-11:00; on call 24 hours
# 24             D1023               Monday-friday, 9am-1, 1:15; 24 hours
# 25             D1025                                      m, w, f 3-6pm
# 26             D1026          normalize normalize: call for appointment
# 27             D1029            normalize: 2nd and 4th saturdays 9am-10
# 28             D1029          Normalize: 2nd and 4th saturdays 9am-10am
# 29             D1030        Normalize: 4th friday of each month at 10am
# 30             D1033  Normalize: 2nd and 4th wednesday from 5:30 - 5...
# 31             D1035  normal normalize normal normal normalize: m-f ...
# 32             D1037  ; food bags given to clients; lunch and snacks...
# 33             D1038                                    Normalize: 24/7
# 34             D1038                                        7 7 program
# 35             D1040  - 5:00 p.m. - 2:00 p.m. - 2:00 p.m./ snack she...
# 36             D1041  Normalize normalize: 1st thand d  1st thursday...
# 37             D1043  Normalize: 2nd and 4th ssat 2nd and 4th sat 10...
# 38             D1045  normalize normalize: 2nd sat 8 8a-11a meals se...
# 39             D1045  Normalize: 2nd sat 8a-11a meals served on site...
